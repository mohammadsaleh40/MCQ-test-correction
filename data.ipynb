# %%
import pandas as pd
import numpy as np

# %%
dict = {}
for i in range(115):
    dict[i] = np.array([])
dict ['UL'] = np.array([])
dict ['UR'] = np.array([])
dict ['DL'] = np.array([])
dict ['DR'] = np.array([])

# %%
df = pd.read_csv("data (copy).csv")

df
# Out:
#         x0     y0     x1     y1     x2     y2     x3     y3     x4     y4  \
# 0   -444.0  519.0  461.0  518.0 -444.0  488.0  461.0  487.0 -444.0  470.0
# 1   -444.0  518.0  461.0  518.0 -444.0  487.0  461.0  487.0 -444.0  470.0
# 2   -444.0  519.0  461.0  519.0 -444.0  487.0  460.0  488.0 -444.0  469.0
# 3   -443.0  519.0  463.0  519.0 -443.0  489.0  463.0  488.0 -443.0  471.0
# 4   -445.0  520.0  461.0  519.0 -445.0  489.0  461.0  488.0 -445.0  472.0
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 198  475.0  486.0 -460.0  485.0  475.0  468.0 -460.0  468.0  474.0  450.0
# 199 -462.0  488.0  475.0  487.0 -462.0  470.0  475.0  469.0 -462.0  452.0
# 200  477.0  488.0 -462.0  488.0  477.0  470.0 -462.0  470.0  476.0  452.0
# 201  477.0  488.0 -463.0  488.0  477.0  469.0 -463.0  470.0  476.0  452.0
# 202  476.0  487.0 -462.0  487.0  476.0  469.0 -462.0  470.0  475.0  451.0
#
#      ...  x114  y114    ULx    ULy    URx    URy    DRx    DRy    DLx    DLy
# ...

# %%
for i in range(115):
    
    
    for j in range(20):
        x = df["x"+str(i)][j]
        y = df["y"+str(i)][j]
        np.append(dict[i],np.array([x,y]))
        
for j in range(20):
    x = df["ULx"][j]
    y = df["ULy"][j]
    np.append(dict['UL'] , np.array([x,y]))
    x = df["URx"][j]
    y = df["URy"][j]
    np.append(dict['UR'] , np.array([x,y]))
    x = df["DRx"][j]
    y = df["DRy"][j]
    np.append(dict['DR'] , np.array([x,y]))
    x = df["DLx"][j]
    y = df["DLy"][j]
    np.append(dict['DL'] , np.array([x,y]))
    
    
dd = pd.DataFrame(dict)

# %%
a = np.array([x,y])

# %%
a
# Out:
# array([-496.,  501.])

# %%
dict
# Out:
# {0: array([], dtype=float64),
#  1: array([], dtype=float64),
#  2: array([], dtype=float64),
#  3: array([], dtype=float64),
#  4: array([], dtype=float64),
#  5: array([], dtype=float64),
#  6: array([], dtype=float64),
#  7: array([], dtype=float64),
#  8: array([], dtype=float64),
#  9: array([], dtype=float64),
#  10: array([], dtype=float64),
#  11: array([], dtype=float64),
#  12: array([], dtype=float64),
#  13: array([], dtype=float64),
#  14: array([], dtype=float64),
#  15: array([], dtype=float64),
#  16: array([], dtype=float64),
#  17: array([], dtype=float64),
#  18: array([], dtype=float64),
#  19: array([], dtype=float64),
#  20: array([], dtype=float64),
#  21: array([], dtype=float64),
#  22: array([], dtype=float64),
#  23: array([], dtype=float64),
#  24: array([], dtype=float64),
#  25: array([], dtype=float64),
#  26: array([], dtype=float64),
#  27: array([], dtype=float64),
#  28: array([], dtype=float64),
#  29: array([], dtype=float64),
# ...

# %%
df.to_csv("data.csv" , index = False)
